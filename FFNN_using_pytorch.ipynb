# %% [markdown]
# <a href="https://colab.research.google.com/github/ssupsandeep/Nerural-networks-and-deep-learning/blob/main/FFNN_using_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim


X = torch.tensor([[0.3, 0.5, 0.4]], dtype=torch.float32)

y = torch.tensor([[1.0]], dtype=torch.float32)

class FeedForwardNN(nn.Module):
    def __init__(self):
        super().__init__()

        self.fc1 = nn.Linear(3, 2)

        self.fc2 = nn.Linear(2, 1)

        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        z1 = self.fc1(x)
        a1 = self.sigmoid(z1)

        z2 = self.fc2(a1)
        a2 = self.sigmoid(z2)

        return a2

model = FeedForwardNN()

criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

epochs = 1000

for epoch in range(epochs):
    output = model(X)

    loss = criterion(output, y)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if epoch % 100 == 0:
        print(f"Epoch {epoch}: Output={output.item():.4f}, Loss={loss.item():.6f}")
# Out:
# Epoch 0: Output=0.4912, Loss=0.258837
# Epoch 100: Output=0.8448, Loss=0.024096
# Epoch 200: Output=0.8973, Loss=0.010554
# Epoch 300: Output=0.9193, Loss=0.006519
# Epoch 400: Output=0.9318, Loss=0.004648
# Epoch 500: Output=0.9401, Loss=0.003584
# Epoch 600: Output=0.9461, Loss=0.002902
# Epoch 700: Output=0.9507, Loss=0.002431
# Epoch 800: Output=0.9543, Loss=0.002087
# Epoch 900: Output=0.9573, Loss=0.001825
