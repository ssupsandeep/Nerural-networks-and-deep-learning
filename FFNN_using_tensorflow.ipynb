# %% [markdown]
# <a href="https://colab.research.google.com/github/ssupsandeep/Nerural-networks-and-deep-learning/blob/main/FFNN_using_tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
X = np.array([[0.3, 0.5, 0.4]], dtype=np.float32)
y = np.array([[1.0]], dtype=np.float32)

model = tf.keras.Sequential([
    tf.keras.layers.Dense(
        2,
        activation='sigmoid',
        input_shape=(3,)
    ),
    tf.keras.layers.Dense(
        1,
        activation='sigmoid'
    )
])

model.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.1),
    loss='mse'
)


history = model.fit(
    X,
    y,
    epochs=1000,
    verbose=0
)

output = model.predict(X)
print("Final Output:", output)


for i in [0, 100, 300, 500, 700, 900]:
    print(f"Epoch {i}, Loss: {history.history['loss'][i]:.6f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Final Output: [[0.9534778]]
# Epoch 0, Loss: 0.241585
# Epoch 100, Loss: 0.033059
# Epoch 300, Loss: 0.008980
# Epoch 500, Loss: 0.004881
# Epoch 700, Loss: 0.003282
# Epoch 900, Loss: 0.002446
